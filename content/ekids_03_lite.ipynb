# %% [markdown]
# # Python. Урок 3
#
# ## Поливаємо дуб 💧🌳
#
# Розгляньте наступний код. Спробуйте здогадатись що він надрукує на екран.
#
# ### Проста програма
#
# ```
# message = "Поливаємо дуб під номером"
# i = 1
# print(message, i)
# i = i + 1
# print(message, i)
# i = i + 2
# print(message, i)
# i = i + 3
# print(message, i)
# ```
#
# <hr />
#
# <details>
# <summary>✅ Перевірте себе ☑</summary>
#
# ![more print statements](data/003_1_print.png)
# </details>

# %%
message = "Поливаємо дуб під номером"
i = 1
print(message, i)
i = i + 1
print(message, i)
i = i + 2
print(message, i)
i = i + 3
print(message, i)

# %% [markdown]
# # Завдання 1 (Пояснення)
#
# Знак `=` виконує дію присвоєння.
# 1. Спочатку обчислюється права частина
# 2. Потім - виразу, що вийшов, клеїться **наліпка** з іменем, яке вказано ліворуч від `=`
#
# ### Що буде якщо одна й та сама змінна, те саме імʼя знаходиться і праворуч і ліворуч?
#
#  `i = i + 1` читається як "Візьми поточне значення, підстав у праву частину. Результат запиши туди само, де взяв поточне значення. Це буде **нове** значення"
#
# > Саме тому, що поточне значення `i` весь час змінювалось ми бачили неочікуваний для когось результат. А саме
#
# ```
# Поливаємо дуб під номером 1
# Поливаємо дуб під номером 2
# Поливаємо дуб під номером 4
# Поливаємо дуб під номером 7
# ```
#
# ## Скорочений запис
#
# Також в мовах програмування часто застосовують скорочений запис `i = i + 1`
#
# який виглядатиме в Python `i += 1`
#
# > ⚠ Зверніть увагу, в Пайтон відсутня форма `i++` яку можна знайти в деяких інших мовах.
#
# Перепишемо код використовуючи скорочену форму **змінюючого присвоєння**

# %%
message = "Поливаємо дуб під номером"
i = 1
print(message, i)
i += 1
print(message, i)
i += 2
print(message, i)
i += 3
print(message, i)

# %% [markdown]
# <hr />
#
# <details>
# <summary>Читати пояснення</summary>
#
# ## Змінююче присвоєння не лише коротше
#
# Форма запису `+=` виглядає коротше, зрозуміліше та економить ресурси компʼютера.
#
# Для інших арифметичних операцій теж існує скорочена форма.
#
# | Повна | Скорочена | Дія |
# | :---: | :---: | :---: |
# | `i = i - 1`| `i -= 1`| Decrement, зменшення на 1 |
# | `i = i * 2`| `i *= 2`| Подвоєння |
# | `i = i / 3`| `i /= 3`| Третина (Десятковий дріб) |
# | `i = i // 4`| `i //= 4`| Частка від цілочисельного ділення на 4 |
# | `i = i % 5`| `i %= 5`| Остача від цілочисельного ділення на 5 |
#
#
# <hr />
#
# **Ціла** частина та **остача** нерідко застосовуються разом, але
#
# буває, що потрібно знати лише частку або лише остачу.
#
# Тому ці 2 операції існують окремо в програмуванні,
#
# на відміну від математики <hr />
#
# > Поміркуйте що буде, якщо виконати наступний код. Дайте відповідь, а потім виконайте код і перевірте себе.
#
# Програма-**тест на кмітливість**
# ```
# x = 0
# print(x)
# x += 2
# print(x)
# x *= 8
# print(x)
# x %= 6
# print(x)
# x //= 2
# print(x)
# ```
# </details>

# %%
x = 0
print(x)
x += 2
print(x)
x *= 8
print(x)
x %= 6
print(x)
x //= 2
print(x)

# %% [markdown]
# # Завдання 2
#
# 1. Зробіть припущення "Що виведе даний код?"
# 2. Виконайте клітинку та подивіться на результат.

# %%
# Початковий "зріст" Дуба
start_height = 100
# Як швидко зростає
growth_per_year = 15
# Кількість років
x = 10
# Зріст через вказану кількість років
height_after_x_years = start_height + growth_per_year * x

# %% [markdown]
# <hr />
#
# <details>
# <summary>Читати пояснення</summary>
#
# ## Забагато змінних
#
# Інколи програмісти створюють занадто багато змінних. Вважається, що додати до програми змінну варто, якщо вона допомагає краще розуміти та краще **вирішувати поставлені задачі**
#
# > Ставити рекорди з кількості змінних не варто. Бо комусь крім вас це ще читати. Та й ресурси компʼютера марнуються.
#
# </details>

# %% [markdown]
# # Завдання 3
#
# 1. Порівняйте з попереднім варіантом. Який вам здається кращим? ЧОМУ?
# 2. Виконайте клітинку та подивіться на результат.

# %%
# Висота Дуба
height = 100
# Як швидко зростає
growth_per_year = 15
# Кількість років
x = 10
# Зріст через вказану кількість років
height += growth_per_year * x

# %% [markdown]
# <hr />
#
# <details>
# <summary>Читати пояснення</summary>
#
# ## На одну менше
#
# Ми скоротили кількість змінних та в цілому спростили програму.
#
# Той хто після вас прийде і читатиме ваш код скаже "ДЯКУЮ" за таку оптимізацію.
#
# </details>

# %% [markdown]
# # Завдання 4 (останнє в уроці)
#
# 1. Оберіть правильну кінцівку програми
# 2. Закоментуйте останній або передостанній рядок.
# 3. Виконайте клітинку та подивіться на результат.
# 4. Поясніть свій вибір

# %%
# Гілок дуба до грози
branches = 100
# Ударів блискавки
thunder_hits = 30
# Кожен сьомий удар завдає шкоди гілці
branches_lost = thunder_hits // 7

branches -= branches_lost

branches_after_storm = branches - branches_lost

# %% [markdown]
# <hr />
#
# <details>
# <summary>Читати пояснення</summary>
#
# ```
# # вводимо нову змінну
# branches = 100
# # також потрібна змінна
# thunder_hits = 30
# # ще одна змінна, яка в цілому допомагає, але не обовʼязкова
# branches_lost = thunder_hits // 7
# # зменшуємо кількість гілок на кількість ударів блискавки
# branches -= branches_lost
# # зайва змінна, адже попереднє значення гілок вже не актуальне і його можна перезаписати
# # branches_after_storm = branches - branches_lost
# ```
#
# ## Трішки роздумів
#
# `Python` цікава та проста мова програмування. В ній приховано ще багато таємниць, які розкриються кожному, хто завзято та наполегливо вчиться.
#
# Програма може бути цілком правильною, але бути не оптимальною, виглядати складніше, ніж потрібно для даної задачі.
#
# Мистецтво програмування - робити **найпростішу** з можливих версій програми, щоб навіть новачки могли второпати, що відбувається.
#
# Якщо писати надмірно складний та незрозумілий код, то інші люди можуть не зрозуміти вашої логіки.
#
# Просту та мінімалістичну програму приємно читати та легко потім змінювати та дописувати.

# %% [markdown]
# # Python. Урок 2
#
# ## Садимо дуб 🌳
#
# Розгляньте наступний код. Спробуйте здогадатись що він надрукує на екран.
#
# ### Проста програма
#
# ```
# i = 1
# print("Садимо дуб під номером", i)
# i = 2
# print("Садимо дуб під номером", i)
# ```
#
# <hr />
#
# <details>
# <summary>✅ Перевірте себе ☑</summary>
#
# ![two print statements](data/002_2_print.png)
# </details>
#
# <hr />
#
# <details>
# <summary>Показати анімацію</summary>
#
# ![change_language_instruction](data/002.gif)
# </details>
#
# ### Типи клітинок (Нагадування)
#
# **блокнот** має 2 типи клітинок:
#
# 1. `Розмітка` - свого роду коментар до коду
# 2. `Код` - власне `Python` код. Такі клітинки відрізняються невеличким прямокутником ліворуч від них.
# А точніше парою квадратних дужок
# - `[ ]` значить дана клітинка коду ще не виконувалась
# - `[*]` ми бачимо рідко, це буває коли код "завис" або потребує часу на виконання.
# - `[5]` або будь-яке інше число вказує на послідовність, в якій виконувались клітинки коду.
#
# > зазвичай ми бачимо числа в порядку зростання згори донизу.
# > Проте якщо повторно виконати одну з попередніх клітинок,
# > тоді це правило порушиться. І це **нормально**  🆗
#
# <hr />
#
# <details>
# <summary>Показати скріншот</summary>
#
# ![cell_types](https://raw.githubusercontent.com/ekidscoding/runpython/refs/heads/main/content/data/002_cell_types.png)
# </details>

# %%
i = 1
print("Садимо дуб під номером", i)
i = 2
print("Садимо дуб під номером", i)

# %% [markdown]
# # Завдання 1 (Повторення)
#
# Виконайте наступну клітинку коду:
# 1. Встановіть курсор на неї
# 2. Натисніть `SHIFT` + `ENTER`
#
# Як варіант також можна скористатись кнопкою `▶`
#
# або
#
# меню `Виконати` -> `Запустити вибрану клітинку`
#
# ## Працює чи ні?
#
# Якщо ліворуч в квадратних дужках `[5]` зʼявилось число та/або одразу під клітинкою коду зʼявився вивід - це ознака того, що код відпрацював належним чином.

# %%
name = 'Василь'
print('Привіт', name)

# %% [markdown]
# <hr />
#
# <details>
# <summary>Читати пояснення</summary>
#
# ## Виклик `print`
#
# Щоразу як викликається функція `print()`, вона аналізує те, що їй передали,
#
# тобто вхідні дані, аргумент (або декілька аргументів по черзі) **впливають** на поведінку функції.
#
# Від вхідних даних залежать вихідні дані, вивід функції.
#
# <hr />
# Змінюючи вхідні дані, ми змінюємо вивід.
# <hr />
#
# > зверніть увагу, **лапки** спочатку та вкінці тексту при друку **відсутні** та змінна `name` була замінена її значенням.
#
# Вивід
# ```
# Привіт Василь
# ```
# </details>

# %% [markdown]
# # Завдання 2
#
# 1. Зробіть припущення "Що виведе даний код?"
# 2. Виконайте клітинку та подивіться на результат.

# %%
community = "e-Kids"
company = "EPAM"
print(company)
print(community)
print(company)

# %% [markdown]
# <hr />
#
# <details>
# <summary>Читати пояснення</summary>
#
# ## Виклик `print`
#
# Щоразу як викликається функція `print()` до кінця рядку додається символ нового рядку (`newline` aka `\n`)
#
# Саме тому слова надруковані кожне на окремому рядку.
#
# Та саме в тому порядку, в якому вказані виклики функції `print()`
#
# Вивід
# ```
# EPAM
# e-Kids
# EPAM
# ```
# </details>

# %% [markdown]
# # Завдання 3
#
# 1. Зробіть припущення "Що виведе наступний код?"
# 2. Виконайте клітинку та подивіться на результат.

# %%
community = "| e-Kids "
company = "| EPAM "
text = community * 2 + company * 3
print(text)

# %% [markdown]
# <hr />
#
# <details>
# <summary>Читати пояснення</summary>
#
# ## Арифметика рядків тексту
#
# Якщо поєднати дією `*` (множення) рядок тексту та число, то рядок повториться декілька разів підряд.
#
# Цю дію можна комбінувати зі звичайним склеюванням (**конкатенацією**) рядків за допомогою знаку `+`
#
# Тому вивід
# ```
# | e-Kids | e-Kids | EPAM | EPAM | EPAM
# ```
# </details>

# %% [markdown]
# # Завдання 4 (останнє в уроці)
#
# 1. Зробіть припущення "Що виведе цей дивний код?"
# 2. Виконайте клітинку та подивіться на результат.

# %%
i = 25
sign = '='
line = sign * i
print(line)

# %% [markdown]
# <hr />
#
# <details>
# <summary>Читати пояснення</summary>
#
# ## Множення змінних
#
# Могло здатись, що ми множимо два текстових рядки, та це не зовсім так.
#
# Ми не можемо помножити 2 рядки, такої дії немає в `Python`.
#
# Також не можемо *ділити, віднімати, підносити* в квадрат
#
# `i` - це числова змінна
# `sign` - символ, текстова змінна
#
# В нашому прикладі виведеться таке
#
# ```
# =========================
# ```
# </details>
#
# Спробуйте змінити значення `i` та `sign` на перезапустити клітинку за допомогою комбінації `SHIFT` + `ENTER`
